# %% [markdown]
# <a href="https://colab.research.google.com/github/STASYA00/AECinCode_tutorials/blob/main/example_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# Airbnb_Open_Data.csv  sample_data

# %%
import pandas as pd

# %%
df = pd.read_csv('Airbnb_Open_Data.csv')
# Out:
# <ipython-input-3-e60a80b46a6c>:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Airbnb_Open_Data.csv')

# %%
df.head()
# Out:
#         id                                              NAME       host id  \
# 0  1001254                Clean & quiet apt home by the park  8.001449e+10
# 1  1002102                             Skylit Midtown Castle  5.233517e+10
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  7.882924e+10
# 3  1002755                                               NaN  8.509833e+10
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  9.203760e+10
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# 3            unconfirmed     Garry            Brooklyn  Clinton Hill
# 4               verified    Lyndon           Manhattan   East Harlem
#
#         lat      long        country  ... service fee minimum nights  \
# 0  40.64749 -73.97237  United States  ...       $193            10.0
# 1  40.75362 -73.98377  United States  ...        $28            30.0
# 2  40.80902 -73.94190  United States  ...       $124             3.0
# 3  40.68514 -73.95976  United States  ...        $74            30.0
# 4  40.79851 -73.94399  United States  ...        $41            10.0
#
#   number of reviews last review  reviews per month review rate number  \
# 0               9.0  10/19/2021               0.21                4.0
# 1              45.0   5/21/2022               0.38                4.0
# 2               0.0         NaN                NaN                5.0
# 3             270.0    7/5/2019               4.64                4.0
# 4               9.0  11/19/2018               0.10                3.0
#
#   calculated host listings count  availability 365  \
# 0                            6.0             286.0
# 1                            2.0             228.0
# 2                            1.0             352.0
# 3                            1.0             322.0
# 4                            1.0             289.0
#
#                                          house_rules license
# 0  Clean up and treat the home the way you'd like...     NaN
# 1  Pet friendly but please confirm with me if the...     NaN
# 2  I encourage you to use my kitchen, cooking and...     NaN
# 3                                                NaN     NaN
# 4  Please no smoking in the house, porch or on th...     NaN
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
df.columns = [x.lower().replace(" ", "_") for x in df.columns]

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long', 'country',
#        'country_code', 'instant_bookable', 'cancellation_policy', 'room_type',
#        'construction_year', 'price', 'service_fee', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'review_rate_number', 'calculated_host_listings_count',
#        'availability_365', 'house_rules', 'license'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94136 entries, 0 to 94135
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              94136 non-null  int64
#  1   name                            93901 non-null  object
#  2   host_id                         94135 non-null  float64
#  3   host_identity_verified          93862 non-null  object
#  4   host_name                       93746 non-null  object
#  5   neighbourhood_group             94106 non-null  object
#  6   neighbourhood                   94119 non-null  object
#  7   lat                             94127 non-null  float64
#  8   long                            94127 non-null  float64
#  9   country                         93771 non-null  object
#  10  country_code                    94035 non-null  object
#  11  instant_bookable                94035 non-null  object
#  12  cancellation_policy             94064 non-null  object
#  13  room_type                       94135 non-null  object
#  14  construction_year               93933 non-null  float64
#  15  price                           93917 non-null  object
#  16  service_fee                     93894 non-null  object
#  17  minimum_nights                  93754 non-null  float64
#  18  number_of_reviews               93955 non-null  float64
#  19  last_review                     79367 non-null  object
#  20  reviews_per_month               79380 non-null  float64
#  21  review_rate_number              93832 non-null  float64
#  22  calculated_host_listings_count  93850 non-null  float64
#  23  availability_365                93687 non-null  float64
#  24  house_rules                     44924 non-null  object
#  25  license                         2 non-null      object
# dtypes: float64(10), int64(1), object(15)
# memory usage: 18.7+ MB

# %%
df.shape[0]
# Out:
# 94136

# %%
df.isna()
# Out:
#           id   name  host_id  host_identity_verified  host_name  \
# 0      False  False    False                   False      False
# 1      False  False    False                   False      False
# 2      False  False    False                    True      False
# 3      False   True    False                   False      False
# 4      False  False    False                   False      False
# ...      ...    ...      ...                     ...        ...
# 94131  False  False    False                   False      False
# 94132  False  False    False                   False      False
# 94133  False  False    False                   False      False
# 94134  False  False    False                   False      False
# 94135  False   True     True                    True       True
#
#        neighbourhood_group  neighbourhood    lat   long  country  ...  \
# 0                    False          False  False  False    False  ...
# 1                    False          False  False  False    False  ...
# 2                    False          False  False  False    False  ...
# 3                    False          False  False  False    False  ...
# 4                    False          False  False  False    False  ...
# ...                    ...            ...    ...    ...      ...  ...
# 94131                False          False  False  False    False  ...
# 94132                False          False  False  False    False  ...
# 94133                False          False  False  False    False  ...
# 94134                False          False  False  False    False  ...
# 94135                 True           True   True   True     True  ...
#
#        service_fee  minimum_nights  number_of_reviews  last_review  \
# 0            False           False              False        False
# 1            False           False              False        False
# 2            False           False              False         True
# 3            False           False              False        False
# 4            False           False              False        False
# ...            ...             ...                ...          ...
# 94131        False           False              False        False
# 94132        False           False              False        False
# 94133        False           False              False        False
# 94134        False           False              False        False
# 94135         True            True               True         True
#
#        reviews_per_month  review_rate_number  calculated_host_listings_count  \
# 0                  False               False                           False
# 1                  False               False                           False
# 2                   True               False                           False
# 3                  False               False                           False
# 4                  False               False                           False
# ...                  ...                 ...                             ...
# 94131              False               False                           False
# 94132              False               False                           False
# 94133              False               False                           False
# 94134              False               False                           False
# 94135               True                True                            True
#
#        availability_365  house_rules  license
# 0                 False        False     True
# 1                 False        False     True
# 2                 False        False     True
# 3                 False         True     True
# 4                 False        False     True
# ...                 ...          ...      ...
# 94131             False        False     True
# 94132             False        False     True
# 94133             False         True     True
# 94134             False         True     True
# 94135              True         True     True
#
# [94136 rows x 26 columns]

# %%
df.isna().sum() / df.shape[0]
# Out:
# id                                0.000000
# name                              0.002496
# host_id                           0.000011
# host_identity_verified            0.002911
# host_name                         0.004143
# neighbourhood_group               0.000319
# neighbourhood                     0.000181
# lat                               0.000096
# long                              0.000096
# country                           0.003877
# country_code                      0.001073
# instant_bookable                  0.001073
# cancellation_policy               0.000765
# room_type                         0.000011
# construction_year                 0.002156
# price                             0.002326
# service_fee                       0.002571
# minimum_nights                    0.004058
# number_of_reviews                 0.001923
# last_review                       0.156890
# reviews_per_month                 0.156752
# review_rate_number                0.003229
# calculated_host_listings_count    0.003038
# availability_365                  0.004770
# house_rules                       0.522776
# license                           0.999979
# dtype: float64

# %%
def drop(df):
  return df - column

# %%
df.drop(columns=["license"], inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long', 'country',
#        'country_code', 'instant_bookable', 'cancellation_policy', 'room_type',
#        'construction_year', 'price', 'service_fee', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'review_rate_number', 'calculated_host_listings_count',
#        'availability_365', 'house_rules'],
#       dtype='object')

# %%
df = df.loc[ df["lat"].isna()==False]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df["reviews_missing"] = df["last_review"].isna()

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_identity_verified', 'host_name',
#        'neighbourhood_group', 'neighbourhood', 'lat', 'long', 'country',
#        'country_code', 'instant_bookable', 'cancellation_policy', 'room_type',
#        'construction_year', 'price', 'service_fee', 'minimum_nights',
#        'number_of_reviews', 'last_review', 'reviews_per_month',
#        'review_rate_number', 'calculated_host_listings_count',
#        'availability_365', 'house_rules', 'reviews_missing'],
#       dtype='object')

# %%
df["construction_year"].mean()
# Out:
# np.float64(2012.4852543491686)

# %%
df["construction_year"].fillna(int(df["construction_year"].mean()), inplace=True)

# %%
df["price"]
# Out:
# 0        $966
# 1        $142
# 2        $620
# 3        $368
# 4        $204
#          ...
# 94130    $740
# 94131    $124
# 94132    $527
# 94133    $374
# 94134    $666
# Name: price, Length: 94127, dtype: object

# %%
df["price"].loc[~df["price"].apply(lambda x: isinstance(x, str))].isna().sum()
# Out:
# np.int64(218)

# %%
df["price"] = df["price"].apply(lambda x: int(x[1:].replace(",", "")) if isinstance(x, str) else 0)

# %%
missing_date = "01/01/2000"

# %%
df["last_review"].fillna(missing_date, inplace=True)
# Out:
# <ipython-input-45-60623817af6e>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["last_review"].fillna(missing_date, inplace=True)

# %%
df["last_review"] = pd.to_datetime(df["last_review"])

# %%
df["last_review"].apply(lambda s: s.weekday())
# Out:
# 0        1
# 1        5
# 2        5
# 3        4
# 4        0
#         ..
# 94130    2
# 94131    2
# 94132    6
# 94133    5
# 94134    1
# Name: last_review, Length: 94127, dtype: int64

# %%
df["neighbourhood_group"].value_counts()
# Out:
# neighbourhood_group
# Manhattan        40345
# Brooklyn         38314
# Queens           12108
# Bronx             2469
# Staten Island      860
# brookln              1
# manhatan             1
# Name: count, dtype: int64

# %%
df["neighbourhood_group"].replace(0, "Brooklyn", inplace=True)
# Out:
# <ipython-input-62-253b98209ebb>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["neighbourhood_group"].replace(0, "Brooklyn", inplace=True)

# %%
pd.get_dummies(df, columns=['neighbourhood_group'], prefix=['neighbourhood'])
# Out:
#              id                                               name  \
# 0       1001254                 Clean & quiet apt home by the park
# 1       1002102                              Skylit Midtown Castle
# 2       1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 3       1002755                                                NaN
# 4       1003689   Entire Apt: Spacious Studio/Loft by central park
# ...         ...                                                ...
# 94130  52989335  Spectacular 1-Bedroom modern apartment in Flat...
# 94131  52989887                                     NYC experience
# 94132  52990440   3 QUEEN size lofts in Williamsburg/grrenpoint!!!
# 94133  52990992                              Artist Warehouse Loft
# 94134  52991544    Beautiful 1 bed, UES - steps from Central Park!
#
#             host_id host_identity_verified host_name    neighbourhood  \
# 0      8.001449e+10            unconfirmed  Madaline       Kensington
# 1      5.233517e+10               verified     Jenna          Midtown
# 2      7.882924e+10                    NaN     Elise           Harlem
# 3      8.509833e+10            unconfirmed     Garry     Clinton Hill
# 4      9.203760e+10               verified    Lyndon      East Harlem
# ...             ...                    ...       ...              ...
# 94130  1.346179e+10            unconfirmed  Santiago          Midtown
# 94131  3.117087e+09               verified    Carlos         Bushwick
# 94132  4.448837e+10               verified     Jimmy       Greenpoint
# 94133  3.654297e+10               verified     Taras        Navy Yard
# 94134  2.505846e+10            unconfirmed   Jocelyn  Upper East Side
#
#             lat      long        country country_code  ... availability_365  \
# 0      40.64749 -73.97237  United States           US  ...            286.0
# 1      40.75362 -73.98377  United States           US  ...            228.0
# 2      40.80902 -73.94190  United States           US  ...            352.0
# 3      40.68514 -73.95976  United States           US  ...            322.0
# 4      40.79851 -73.94399  United States           US  ...            289.0
# ...         ...       ...            ...          ...  ...              ...
# 94130  40.74383 -73.98387  United States           US  ...              0.0
# 94131  40.69355 -73.91829  United States           US  ...            365.0
# 94132  40.72552 -73.95647  United States           US  ...             14.0
# 94133  40.69792 -73.96406  United States           US  ...              0.0
# 94134  40.77905 -73.95275  United States           US  ...              3.0
#
#                                              house_rules reviews_missing  \
# 0      Clean up and treat the home the way you'd like...           False
# 1      Pet friendly but please confirm with me if the...           False
# 2      I encourage you to use my kitchen, cooking and...            True
# 3                                                    NaN           False
# 4      Please no smoking in the house, porch or on th...           False
# ...                                                  ...             ...
# 94130  Please leave shoes at the front door. Guests s...           False
# 94131                                             #NAME?           False
# 94132  Please be respectful of other guests.  Keep th...           False
# 94133                                                NaN           False
# 94134                                                NaN           False
#
#        neighbourhood_Bronx  neighbourhood_Brooklyn neighbourhood_Manhattan  \
# 0                    False                    True                   False
# 1                    False                   False                    True
# 2                    False                   False                    True
# 3                    False                    True                   False
# 4                    False                   False                    True
# ...                    ...                     ...                     ...
# 94130                False                   False                    True
# 94131                False                    True                   False
# 94132                False                    True                   False
# 94133                False                    True                   False
# 94134                False                   False                    True
#
#        neighbourhood_Queens  neighbourhood_Staten Island  \
# 0                     False                        False
# 1                     False                        False
# 2                     False                        False
# 3                     False                        False
# 4                     False                        False
# ...                     ...                          ...
# 94130                 False                        False
# 94131                 False                        False
# 94132                 False                        False
# 94133                 False                        False
# 94134                 False                        False
#
#       neighbourhood_brookln  neighbourhood_manhatan
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                   False
# 4                     False                   False
# ...                     ...                     ...
# 94130                 False                   False
# 94131                 False                   False
# 94132                 False                   False
# 94133                 False                   False
# 94134                 False                   False
#
# [94127 rows x 32 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
encoder.fit(df['neighbourhood_group'])
# Out:
# LabelEncoder()

# %%
encoder.classes_
# Out:
# array(['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island',
#        'manhatan', nan], dtype=object)

# %%
encoder.transform(df['neighbourhood_group'])
# Out:
# array([1, 2, 2, ..., 1, 1, 2])
